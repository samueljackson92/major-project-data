# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import mia

# %% [markdown]
# #Loading and Preprocessing

# %% [markdown]
# Loading the hologic and synthetic datasets.

# %%
hologic = pd.DataFrame.from_csv("hologic_blobs.csv")
phantom = pd.DataFrame.from_csv("synthetic_blobs.csv")

# %% [markdown]
# Loading the meta data for the real and synthetic datasets.

# %%
hologic_meta = mia.analysis.create_hologic_meta_data(hologic, "meta_data/real_meta.csv")
phantom_meta = mia.analysis.create_synthetic_meta_data(phantom, "meta_data/synthetic_meta.csv")
phantom_meta.index.name = 'img_name'

# %% [markdown]
# Prepare the BI-RADS/VBD labels for both datasets.

# %%
hologic_labels = hologic_meta.drop_duplicates().BIRADS
phantom_labels = phantom_meta['VBD.1']

class_labels = pd.concat([hologic_labels, phantom_labels])
class_labels.index.name = "img_name"
labels = mia.analysis.remove_duplicate_index(class_labels)[0]

# %% [markdown]
# # Creating Features

# %% [markdown]
# Create blob features from distribution of blobs

# %%
hologic_blob_features = mia.analysis.features_from_blobs(hologic)
phantom_blob_features = mia.analysis.features_from_blobs(phantom)

# %% [markdown]
# Take a random subset of the phantom mammograms. This is important so that each case is not over represented.

# %%
syn_feature_meta = mia.analysis.remove_duplicate_index(phantom_meta)
phantom_blob_features['phantom_name'] = syn_feature_meta.phantom_name.tolist()
phantom_blob_features_subset = mia.analysis.create_random_subset(phantom_blob_features, 'phantom_name')

# %% [markdown]
# Combine the features from both datasets.

# %%
features = pd.concat([hologic_blob_features, phantom_blob_features_subset])
assert features.shape[0] == 366
features.head()
# Out:
#                        blob_count  avg_radius  std_radius  min_radius  \
# p214-010-60001-cl.png          56   22.121831   22.923389           8
# p214-010-60001-cr.png          78   19.054538   17.506086           8
# p214-010-60001-ml.png          98   20.011191   21.876304           8
# p214-010-60001-mr.png         139   15.309764   15.307860           8
# p214-010-60005-cl.png          97   20.132590   23.255605           8
#
#                        max_radius  small_radius_count  med_radius_count  \
# p214-010-60001-cl.png  128.000000                  52                 1
# p214-010-60001-cr.png   90.509668                  68                 4
# p214-010-60001-ml.png  128.000000                  90                 3
# p214-010-60001-mr.png  128.000000                 136                 1
# p214-010-60005-cl.png  181.019336                  94                 2
#
#                        large_radius_count    density  upper_dist_count  25%  \
# p214-010-60001-cl.png                   3  52.940812                21    8
# p214-010-60001-cr.png                   6  40.749811                22    8
# p214-010-60001-ml.png                   5  42.644057                27    8
# p214-010-60001-mr.png                   2  38.287439                40    8
# p214-010-60005-cl.png                   1  41.456308                27    8
#
#                              50%        75%
# p214-010-60001-cl.png  11.313708  22.627417
# p214-010-60001-cr.png  11.313708  22.627417
# p214-010-60001-ml.png  11.313708  22.627417
# p214-010-60001-mr.png  11.313708  16.000000
# p214-010-60005-cl.png  11.313708  22.627417

# %% [markdown]
# Filter some features, such as the min, to remove noise.

# %%
selected_features = features.drop(['min_radius'], axis=1)

# %% [markdown]
# # Compare Real and Synthetic Detections

# %% [markdown]
# Compare the distributions of features detected from the real mammograms and the phantoms using the Kolmogorov-Smirnov two sample test.

# %%
ks_stats = [list(stats.ks_2samp(hologic_blob_features[col], phantom_blob_features[col])) 
            for col in hologic_blob_features.columns]
ks_test = pd.DataFrame(ks_stats, columns=['KS', 'p-value'], index=hologic_blob_features.columns)
ks_test.to_latex("blob_features_ks.tex")
ks_test
# Out:
#                           KS       p-value
# blob_count          0.341667  2.774753e-07
# avg_radius          0.847222  1.360953e-42
# std_radius          0.711111  3.929143e-30
# min_radius          0.000000  1.000000e+00
# max_radius          0.363889  3.327680e-08
# small_radius_count  0.319444  2.024353e-06
# med_radius_count    0.338889  3.583275e-07
# large_radius_count  0.733333  5.112303e-32
# density             0.169444  4.114705e-02
# upper_dist_count    0.345833  1.883393e-07
# 25%                 0.358333  5.726005e-08
# 50%                 0.743056  7.334764e-33
# 75%                 0.777778  5.796838e-36

# %% [markdown]
# #t-SNE
# Running t-SNE to obtain a two dimensional representation.

# %%
kwargs = {
    'learning_rate': 300,
    'perplexity': 40,
    'verbose': 1
}

# %%
SNE_mapping_2d = mia.analysis.tSNE(selected_features, n_components=2, **kwargs)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 366 / 366
# [t-SNE] Mean sigma: 1.103315
# [t-SNE] Error after 83 iterations with early exaggeration: 12.238734
# [t-SNE] Error after 272 iterations: 0.342380

# %%
mia.plotting.plot_mapping_2d(SNE_mapping_2d, hologic_blob_features.index, phantom_blob_features.index, labels)
plt.savefig('figures/mappings/SNE_mapping_2d.png', dpi=300)

# %% [markdown]
# Running t-SNE to obtain a 3 dimensional mapping

# %%
SNE_mapping_3d = mia.analysis.tSNE(selected_features, n_components=3, **kwargs)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 366 / 366
# [t-SNE] Mean sigma: 1.103315
# [t-SNE] Error after 83 iterations with early exaggeration: 12.736704
# [t-SNE] Error after 312 iterations: 0.321288

# %%
mia.plotting.plot_mapping_3d(SNE_mapping_3d, hologic_blob_features.index, phantom_blob_features.index, labels)
plt.savefig('figures/mappings/SNE_mapping_3d.png', dpi=300)

# %% [markdown]
# #Isomap
# Running Isomap to obtain a 2 dimensional mapping

# %%
iso_kwargs = {
    'n_neighbors': 8,
}

# %%
iso_mapping_2d = mia.analysis.isomap(selected_features, n_components=2, **iso_kwargs)

# %%
mia.plotting.plot_mapping_2d(iso_mapping_2d, hologic_blob_features.index, phantom_blob_features.index, labels)
plt.savefig('figures/mappings/iso_mapping_2d.png', dpi=300)

# %%
iso_mapping_3d = mia.analysis.isomap(selected_features, n_components=3, **iso_kwargs)

# %%
mia.plotting.plot_mapping_3d(iso_mapping_3d, hologic_blob_features.index, phantom_blob_features.index, labels)
plt.savefig('figures/mappings/iso_mapping_3d.png', dpi=300)

# %% [markdown]
# #Locally Linear Embedding
# Running locally linear embedding to obtain 2d mapping

# %%
lle_kwargs = {
    'n_neighbors': 8,
}

# %%
lle_mapping_2d = mia.analysis.lle(selected_features, n_components=2, **lle_kwargs)

# %%
mia.plotting.plot_mapping_2d(lle_mapping_2d, hologic_blob_features.index, phantom_blob_features.index, labels)
plt.savefig('figures/mappings/lle_mapping_2d.png', dpi=300)

# %%
lle_mapping_3d = mia.analysis.lle(selected_features, n_components=3, **lle_kwargs)

# %%
mia.plotting.plot_mapping_3d(lle_mapping_3d, hologic_blob_features.index, phantom_blob_features.index, labels)
plt.savefig('figures/mappings/lle_mapping_3d.png', dpi=300)

# %% [markdown]
# ## Quality Assessment of Dimensionality Reduction

# %% [markdown]
# Assess the quality of the DR against measurements from the co-ranking matrices. First create co-ranking matrices for each of the dimensionality reduction mappings

# %%
SNE_mapping_2d_cm = mia.coranking.coranking_matrix(selected_features, SNE_mapping_2d)
iso_mapping_2d_cm = mia.coranking.coranking_matrix(selected_features, iso_mapping_2d)
lle_mapping_2d_cm = mia.coranking.coranking_matrix(selected_features, lle_mapping_2d)

SNE_mapping_3d_cm = mia.coranking.coranking_matrix(selected_features, SNE_mapping_3d)
iso_mapping_3d_cm = mia.coranking.coranking_matrix(selected_features, iso_mapping_3d)
lle_mapping_3d_cm = mia.coranking.coranking_matrix(selected_features, lle_mapping_3d)

# %% [markdown]
# ### 2D Mappings

# %%
SNE_trustworthiness_2d = [mia.coranking.trustworthiness(SNE_mapping_2d_cm, k) for k in range(1, 365)]
iso_trustworthiness_2d = [mia.coranking.trustworthiness(iso_mapping_2d_cm, k) for k in range(1, 365)]
lle_trustworthiness_2d = [mia.coranking.trustworthiness(lle_mapping_2d_cm, k) for k in range(1, 365)]

# %%
trustworthiness_df = pd.DataFrame([SNE_trustworthiness_2d,
                                   iso_trustworthiness_2d,
                                   lle_trustworthiness_2d], 
                                   index=['SNE', 'Isomap', 'LLE']).T
trustworthiness_df.plot()
plt.savefig('figures/quality_measures/trustworthiness_2d.png', dpi=300)

# %%
SNE_continuity_2d = [mia.coranking.continuity(SNE_mapping_2d_cm, k) for k in range(1, 365)]
iso_continuity_2d = [mia.coranking.continuity(iso_mapping_2d_cm, k) for k in range(1, 365)]
lle_continuity_2d = [mia.coranking.continuity(lle_mapping_2d_cm, k) for k in range(1, 365)]

# %%
continuity_df = pd.DataFrame([SNE_continuity_2d,
                              iso_continuity_2d,
                              lle_continuity_2d], 
                              index=['SNE', 'Isomap', 'LLE']).T
continuity_df.plot()
plt.savefig('figures/quality_measures/continuity_2d.png', dpi=300)

# %%
SNE_lcmc_2d = [mia.coranking.LCMC(SNE_mapping_2d_cm, k) for k in range(2, 365)]
iso_lcmc_2d = [mia.coranking.LCMC(iso_mapping_2d_cm, k) for k in range(2, 365)]
lle_lcmc_2d = [mia.coranking.LCMC(lle_mapping_2d_cm, k) for k in range(2, 365)]

# %%
lcmc_df = pd.DataFrame([SNE_lcmc_2d,
                        iso_lcmc_2d,
                        lle_lcmc_2d], 
                        index=['SNE', 'Isomap', 'LLE']).T
lcmc_df.plot()
plt.savefig('figures/quality_measures/lcmc_2d.png', dpi=300)

# %% [markdown]
# ### 3D Mappings

# %%
SNE_trustworthiness_3d = [mia.coranking.trustworthiness(SNE_mapping_3d_cm, k) for k in range(1, 365)]
iso_trustworthiness_3d = [mia.coranking.trustworthiness(iso_mapping_3d_cm, k) for k in range(1, 365)]
lle_trustworthiness_3d = [mia.coranking.trustworthiness(lle_mapping_3d_cm, k) for k in range(1, 365)]

# %%
trustworthiness3d_df = pd.DataFrame([SNE_trustworthiness_3d,
                                   iso_trustworthiness_3d,
                                   lle_trustworthiness_3d], 
                                   index=['SNE', 'Isomap', 'LLE']).T
trustworthiness3d_df.plot()
plt.savefig('figures/quality_measures/trustworthiness_3d.png', dpi=300)

# %%
SNE_continuity_3d = [mia.coranking.continuity(SNE_mapping_3d_cm, k) for k in range(1, 365)]
iso_continuity_3d = [mia.coranking.continuity(iso_mapping_3d_cm, k) for k in range(1, 365)]
lle_continuity_3d = [mia.coranking.continuity(lle_mapping_3d_cm, k) for k in range(1, 365)]

# %%
continuity3d_df = pd.DataFrame([SNE_continuity_3d,
                              iso_continuity_3d,
                              lle_continuity_3d], 
                              index=['SNE', 'Isomap', 'LLE']).T
continuity3d_df.plot()
plt.savefig('figures/quality_measures/continuity_3d.png', dpi=300)

# %%
SNE_lcmc_3d = [mia.coranking.LCMC(SNE_mapping_3d_cm, k) for k in range(2, 365)]
iso_lcmc_3d = [mia.coranking.LCMC(iso_mapping_3d_cm, k) for k in range(2, 365)]
lle_lcmc_3d = [mia.coranking.LCMC(lle_mapping_3d_cm, k) for k in range(2, 365)]

# %%
lcmc3d_df = pd.DataFrame([SNE_lcmc_3d,
                        iso_lcmc_3d,
                        lle_lcmc_3d], 
                        index=['SNE', 'Isomap', 'LLE']).T
lcmc3d_df.plot()
plt.savefig('figures/quality_measures/lcmc_3d.png', dpi=300)
